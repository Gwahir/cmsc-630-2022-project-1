# %%
import numpy as np
import numpy.lib.stride_tricks as slide
import imageio as iio
import multiprocessing
import re
import io
import math
import glob
import tools

class Sample:
    def __init__(self, path):
        self.path = path
        classMatch = re.search('[\\\/]([a-zA-Z]+)(\d+)\.(\w+)', path)
        self.klass = classMatch.group(1).lower()
        self.number = int(classMatch.group(2))
        self.extension = classMatch.group(3)
        self.klassId = tools.CLASSES.index(self.klass)
        
    def __str__(self):
        return f'{self.path} {self.klass} {self.number}'
    def __repr__(self):
        return f'{self.path} {self.klass} {self.number}'
        
    def readImage(self):
        return iio.imread(self.path)
    
    def writeImage(self, buffer, base, extension):
        if not extension:
            extension = self.extension
        iio.imgwrite(f'{base}/{self.klass}{str(self.number).zfill(3)}.{extension}', buffer)
        


def buildSampleList(pathGlob):
    samples = []
    for i, filePath in enumerate(glob.glob(pathGlob)):
        samples.append(Sample(filePath))
    return samples;

# %%
def kFold(grid, classifier, k=10, stratify=False):
    data = np.random.shuffle(grid.clone())
    for i in range(0,k):
        test = data[i]
        train = np.delete(data, k, axis=0)
        
def KNN(reference, challenge, k = 10):
    """hi"""

def compareOverlay(base, oppose):
    return np.count(base - oppose) / np.count(base)

def extractSegmentFeatures(patch, steps = 10):
    step = 2.0*math.pi / steps
    accum = 0
    origSize = np.count_nonzero(patch)
    side = np.max(patch.shape)
    padding = ((side - patch.shape[0] + side) // 2, (side - patch.shape[1] + side) // 2)
    padded = np.pad(patch, padding)
    com = scipy.ndimage.center_of_mass(padded)
    line = np.zeros(padded.shape)
    line[round(com[0])] = 1
    perim = np.count_nonzero(padded ^ scipy.ndimage.binary_erosion(padded))
    
    
    
    diameters = []
    for i in range(steps):
        newPatch = scipy.ndimage.rotate(padded, i * step, reshape=False)
        accum = accum + np.count_nonzero(padded * newPatch)
        diameters.append(np.count_nonzero(newPatch * line))
    dMin = np.min(diameters)
    dMax = np.max(diameters)
    
    return [com[0], com[1], accum /  steps, dMin, dMax, dMax / dMin, perim]

def averageIntensity(object, patch, gray):
    np.mean(gray[object] * patch.astype(np.uint8))
    
def averageColor(object, patch, color):
    np.mean(color[object] * patch.astype(np.uint8), axis=(0,1))

def com(patch):
    cm = scipy.ndimage.center_of_mass(patch)
    return math.sqrt(cm[0] ** 2 + cm[1] ** 2)

# %%
import matplotlib.pylab as plt
import matplotlib.pyplot as plot
import scipy;
samples = buildSampleList('./images/*')

def medianFilter(input, kernel, mode='edge'):
    slid = tools.slideKernel(input, kernel, mode)
    flat = slid.reshape((slid.shape[0], slid.shape[1], slid.shape[2] * slid.shape[3]))
    
    return np.median(flat, axis=2)


#samples = np.random.choice(samples, 20)
medianKernel = np.ones((7,7))
discMask = tools.makeBooleanDisc(5)

def area(sliceT, img):
    return np.asarray(img[sliceT]).size
    

def processAndPlot(sample):
    original = sample.readImage()
    #buffer = np.zeros(img.shape[0:2], dtype=img.dtype)
    
    # img = tools.rgbToLuminosity(original)
    # img = tools.autoThresholdSegmentation(img)
    # img = medianFilter(img, medianKernel)
    # img = tools.shrinkAndGrow(img, discMask, steps=3)
    # img = tools.growAndShrink(img, discMask, steps=2)
    # img = tools.shrinkAndGrow(img, discMask, steps=2)
    
    gray = tools.rgbToLuminosity(original)
    img = scipy.ndimage.median_filter(gray, size=5)
    img = tools.autoThresholdSegmentation(img)
    #img = tools.shrinkAndGrow(img, discMask, steps=3).astype(np.uint8)
    img = scipy.ndimage.binary_erosion(img, discMask, 5)
    img = scipy.ndimage.binary_dilation(img, discMask, 5)
    
    markerSource = scipy.ndimage.binary_erosion(img, discMask, 5)
    markers, _ = scipy.ndimage.label(markerSource)
    
    
    img = img.astype(np.uint8)
    
    # xm, ym = np.ogrid[0:img.shape[0]:10, 0:img.shape[1]:10]
    # markers = np.zeros_like(img).astype(np.int16)
    # markers[xm, ym]= np.arange(xm.size*ym.size).reshape((xm.size,ym.size))
    img = scipy.ndimage.watershed_ift(img, markers)
    #img[xm, ym] = img[xm-1, ym-1]
    
    objects = scipy.ndimage.find_objects(img)
    #objects = objects[type(objects) is tuple]
    minXLen = 10
    minYLen = 10
    maxXLen = img.shape[0] // 1.9
    maxYLen = img.shape[1] // 1.9
    objects = [a for a in objects 
               if a != None and 
               (a[0].stop - a[0].start) > minXLen and 
               (a[0].stop - a[0].start) < maxXLen and 
               (a[1].stop - a[1].start) > minYLen and 
               (a[1].stop - a[1].start) < maxYLen]
    areas = [(a[0].stop - a[0].start) * (a[1].stop - a[1].start) for a in objects]
    areaIndices = np.argsort(areas);
    objects = [objects[i] for i in areaIndices]
    
    if len(objects) > 7:
        midIndex = len(objects)//2
        objects = objects[midIndex:]
        
    
    patches = [img[obj] for obj in objects]
    
    
    patches = [np.choose(p  == p[p.shape[0]//2, p.shape[1]//2], [0,1]) for p in patches]
    
    
    try:
        meanIntensity = np.mean(gray[objects[0]] * patches[0].astype(np.uint8))
    except:
        meanIntensity = gray[gray.shape[0] // 2, gray.shape[1] // 2]
    try:
        meanColor = np.mean(original[objects[0]] * tools.intensityToRgb(patches[0].astype(np.uint8)), axis=(0,1))
    except:
        meanColor = original[original.shape[0] // 2, original.shape[1] // 2]
    
    features = []
    for patch in patches:
        meanIntensity = np.mean(gray[objects[0]] * patches[0].astype(np.uint8))
        meanColor = np.mean(original[objects[0]] * tools.intensityToRgb(patches[0].astype(np.uint8)), axis=(0,1))
        featureVec = extractSegmentFeatures(patch)
        featureVec.append(meanIntensity)
        featureVec.append(meanColor[0])
        featureVec.append(meanColor[1])
        featureVec.append(meanColor[2])
        featureVec.append(sample.klassId)
        if len(features) == 0: 
            features = np.asarray(featureVec)
        else:
            features[0] += featureVec[0]
            features[1] += featureVec[1]
            features[2] = min(features[2], featureVec[2])
            features[3] += featureVec[3]
            features[4] += featureVec[4]
            features[5] += featureVec[5]
            features[6] += featureVec[6]
            
            features[7] += featureVec[7]
            features[8] += featureVec[8]
            features[9] += featureVec[9]
            features[10] += featureVec[10]
            
            
    length = len(patches)
    features[0] /= length
    features[1] /= length

    features[3] /= length
    features[4] /= length
    features[5] /= length
    features[6] /= length
    features[7] /= length
    features[8] /= length
    features[9] /= length
    features[10] /= length
    
    
    plt.figure()
    plt.title(sample.path + ' original')
    plt.imshow(original)
    
    plt.figure()
    plt.title(sample.path)
    plt.imshow(img, cmap='gray')
    
    for patch in patches:
        plt.figure()
        plt.imshow(patch, cmap='gray')
        
    return objects


def process(sample):
    original = sample.readImage()
    #buffer = np.zeros(img.shape[0:2], dtype=img.dtype)
    
    # img = tools.rgbToLuminosity(original)
    # img = tools.autoThresholdSegmentation(img)
    # img = medianFilter(img, medianKernel)
    # img = tools.shrinkAndGrow(img, discMask, steps=3)
    # img = tools.growAndShrink(img, discMask, steps=2)
    # img = tools.shrinkAndGrow(img, discMask, steps=2)
    
    gray = tools.rgbToLuminosity(original)
    img = scipy.ndimage.median_filter(gray, size=5)
    img = tools.autoThresholdSegmentation(img)
    #img = tools.shrinkAndGrow(img, discMask, steps=3).astype(np.uint8)
    img = scipy.ndimage.binary_erosion(img, discMask, 5)
    img = scipy.ndimage.binary_dilation(img, discMask, 5)
    
    markerSource = scipy.ndimage.binary_erosion(img, discMask, 5)
    markers, _ = scipy.ndimage.label(markerSource)
    
    
    img = img.astype(np.uint8)
    
    # xm, ym = np.ogrid[0:img.shape[0]:10, 0:img.shape[1]:10]
    # markers = np.zeros_like(img).astype(np.int16)
    # markers[xm, ym]= np.arange(xm.size*ym.size).reshape((xm.size,ym.size))
    img = scipy.ndimage.watershed_ift(img, markers)
    #img[xm, ym] = img[xm-1, ym-1]
    
    objects = scipy.ndimage.find_objects(img)
    #objects = objects[type(objects) is tuple]
    minXLen = 10
    minYLen = 10
    maxXLen = img.shape[0] // 1.9
    maxYLen = img.shape[1] // 1.9
    objects = [a for a in objects 
               if a != None and 
               (a[0].stop - a[0].start) > minXLen and 
               (a[0].stop - a[0].start) < maxXLen and 
               (a[1].stop - a[1].start) > minYLen and 
               (a[1].stop - a[1].start) < maxYLen]
    areas = [(a[0].stop - a[0].start) * (a[1].stop - a[1].start) for a in objects]
    areaIndices = np.argsort(areas);
    objects = [objects[i] for i in areaIndices]
    
    if len(objects) > 7:
        midIndex = len(objects)//2
        objects = objects[midIndex:]
        
    
    patches = [img[obj] for obj in objects]
    patches = [np.choose(p  == p[p.shape[0]//2, p.shape[1]//2], [0,1]) for p in patches]
    
    try:
        meanIntensity = np.mean(gray[objects[0]] * patches[0].astype(np.uint8))
    except:
        meanIntensity = gray[gray.shape[0] // 2, gray.shape[1] // 2]
    try:
        meanColor = np.mean(original[objects[0]] * tools.intensityToRgb(patches[0].astype(np.uint8)), axis=(0,1))
    except:
        meanColor = original[original.shape[0] // 2, original.shape[1] // 2]
    
    features = []
    for patch in patches:
        meanIntensity = np.mean(gray[objects[0]] * patches[0].astype(np.uint8))
        meanColor = np.mean(original[objects[0]] * tools.intensityToRgb(patches[0].astype(np.uint8)), axis=(0,1))
        featureVec = extractSegmentFeatures(patch)
        featureVec.append(meanIntensity)
        featureVec.append(meanColor[0])
        featureVec.append(meanColor[1])
        featureVec.append(meanColor[2])
        featureVec.append(sample.klassId)
        if len(features) == 0: 
            features = np.asarray(featureVec)
        else:
            features[0] += featureVec[0]
            features[1] += featureVec[1]
            features[2] = min(features[2], featureVec[2])
            features[3] += featureVec[3]
            features[4] += featureVec[4]
            features[5] += featureVec[5]
            features[6] += featureVec[6]
            
            features[7] += featureVec[7]
            features[8] += featureVec[8]
            features[9] += featureVec[9]
            features[10] += featureVec[10]
            
    if len(features) == 0:
        f = np.zeros(12)
        f[11] = sample.klassId
        return f
    
    length = len(patches)
    features[0] /= length
    features[1] /= length

    features[3] /= length
    features[4] /= length
    features[5] /= length
    features[6] /= length
    features[7] /= length
    features[8] /= length
    features[9] /= length
    features[10] /= length
    
    
    return features

# %%
def processSamples(samples, fileName = 'data.npy'):
    data = []

    numSamples = len(samples)
    print(f'Number of Samples: {numSamples}')

    for i, sample in enumerate(samples):
        print(i, sample.path)
        data.append(process(sample))
        if i % 10 == 0:
            print(f'Processed: {i} ({100 * i / numSamples}%)')



    np.save('data.npy', data, allow_pickle=False)
    return data

#data = processSamples(samples)
# Out:
# Number of Samples: 499
# 0 ./images\cyl01.BMP
# Processed: 0 (0.0%)
# 1 ./images\cyl02.BMP
# 2 ./images\cyl03.BMP
# 3 ./images\cyl04.BMP
# 4 ./images\cyl05.BMP
# 5 ./images\cyl06.BMP
# 6 ./images\cyl07.BMP
# 7 ./images\cyl08.BMP
# 8 ./images\cyl09.BMP
# 9 ./images\cyl10.BMP
# 10 ./images\cyl11.BMP
# Processed: 10 (2.004008016032064%)
# 11 ./images\cyl12.BMP
# 12 ./images\cyl13.BMP
# 13 ./images\cyl14.BMP
# 14 ./images\cyl15.BMP
# 15 ./images\cyl16.BMP
# 16 ./images\cyl17.BMP
# 17 ./images\cyl18.BMP
# 18 ./images\cyl19.BMP
# 19 ./images\cyl20.BMP
# 20 ./images\cyl21.BMP
# Processed: 20 (4.008016032064128%)
# 21 ./images\cyl22.BMP
# 22 ./images\cyl23.BMP
# 23 ./images\cyl24.BMP
# 24 ./images\cyl25.BMP
# 25 ./images\cyl26.BMP
# 26 ./images\cyl27.BMP
# 27 ./images\cyl28.BMP
# 28 ./images\cyl29.BMP
# 29 ./images\cyl30.BMP
# 30 ./images\cyl31.BMP
# Processed: 30 (6.012024048096192%)
# 31 ./images\cyl32.BMP
# 32 ./images\cyl33.BMP
# 33 ./images\cyl34.BMP
# 34 ./images\cyl35.BMP
# 35 ./images\cyl36.BMP
# 36 ./images\cyl37.BMP
# 37 ./images\cyl38.BMP
# 38 ./images\cyl39.BMP
# 39 ./images\cyl40.BMP
# 40 ./images\cyl41.BMP
# Processed: 40 (8.016032064128256%)
# 41 ./images\cyl42.BMP
# 42 ./images\cyl43.BMP
# 43 ./images\cyl44.BMP
# 44 ./images\cyl45.BMP
# 45 ./images\cyl46.BMP
# 46 ./images\cyl47.BMP
# 47 ./images\cyl48.BMP
# 48 ./images\cyl49.BMP
# 49 ./images\cyl50.BMP
# 50 ./images\inter01.BMP
# Processed: 50 (10.02004008016032%)
# 51 ./images\inter02.BMP
# 52 ./images\inter03.BMP
# 53 ./images\inter04.BMP
# 54 ./images\inter05.BMP
# 55 ./images\inter06.BMP
# 56 ./images\inter07.BMP
# 57 ./images\inter08.BMP
# 58 ./images\inter09.BMP
# 59 ./images\inter10.BMP
# 60 ./images\inter11.BMP
# Processed: 60 (12.024048096192384%)
# 61 ./images\inter12.BMP
# 62 ./images\inter13.BMP
# 63 ./images\inter14.BMP
# 64 ./images\inter15.BMP
# 65 ./images\inter16.BMP
# 66 ./images\inter17.BMP
# 67 ./images\inter18.BMP
# 68 ./images\inter19.BMP
# 69 ./images\inter20.BMP
# 70 ./images\inter21.BMP
# Processed: 70 (14.02805611222445%)
# 71 ./images\inter22.BMP
# 72 ./images\inter23.BMP
# 73 ./images\inter24.BMP
# 74 ./images\inter25.BMP
# 75 ./images\inter26.BMP
# 76 ./images\inter27.BMP
# 77 ./images\inter28.BMP
# 78 ./images\inter29.BMP
# 79 ./images\inter30.BMP
# 80 ./images\inter31.BMP
# Processed: 80 (16.03206412825651%)
# 81 ./images\inter32.BMP
# 82 ./images\inter33.BMP
# 83 ./images\inter34.BMP
# 84 ./images\inter35.BMP
# 85 ./images\inter36.BMP
# 86 ./images\inter37.BMP
# 87 ./images\inter38.BMP
# 88 ./images\inter39.BMP
# 89 ./images\inter40.BMP
# 90 ./images\inter41.BMP
# Processed: 90 (18.03607214428858%)
# 91 ./images\inter42.BMP
# 92 ./images\inter43.BMP
# 93 ./images\inter44.BMP
# 94 ./images\inter45.BMP
# 95 ./images\inter46.BMP
# 96 ./images\inter47.BMP
# 97 ./images\inter48.BMP
# 98 ./images\inter49.BMP
# 99 ./images\inter50.BMP
# 100 ./images\let01.BMP
# Processed: 100 (20.04008016032064%)
# 101 ./images\let02.BMP
# 102 ./images\let03.BMP
# 103 ./images\let04.BMP
# 104 ./images\let05.BMP
# 105 ./images\let06.BMP
# 106 ./images\let07.BMP
# 107 ./images\let08.BMP
# 108 ./images\let09.BMP
# 109 ./images\let10.BMP
# 110 ./images\let100.BMP
# Processed: 110 (22.044088176352705%)
# 111 ./images\let11.BMP
# 112 ./images\let12.BMP
# 113 ./images\let13.BMP
# 114 ./images\let14.BMP
# 115 ./images\let15.BMP
# 116 ./images\let16.BMP
# 117 ./images\let17.BMP
# 118 ./images\let18.BMP
# 119 ./images\let19.BMP
# 120 ./images\let20.BMP
# Processed: 120 (24.04809619238477%)
# 121 ./images\let21.BMP
# 122 ./images\let22.BMP
# 123 ./images\let23.BMP
# 124 ./images\let24.BMP
# 125 ./images\let25.BMP
# 126 ./images\let26.BMP
# 127 ./images\let27.BMP
# 128 ./images\let28.BMP
# 129 ./images\let29.BMP
# 130 ./images\let30.BMP
# Processed: 130 (26.052104208416832%)
# 131 ./images\let31.BMP
# 132 ./images\let32.BMP
# 133 ./images\let33.BMP
# 134 ./images\let34.BMP
# 135 ./images\let35.BMP
# 136 ./images\let36.BMP
# 137 ./images\let37.BMP
# 138 ./images\let38.BMP
# 139 ./images\let39.BMP
# 140 ./images\let40.BMP
# Processed: 140 (28.0561122244489%)
# 141 ./images\let41.BMP
# 142 ./images\let42.BMP
# 143 ./images\let43.BMP
# 144 ./images\let44.BMP
# 145 ./images\let45.BMP
# 146 ./images\let46.BMP
# 147 ./images\let47.BMP
# 148 ./images\let48.BMP
# 149 ./images\let49.BMP
# 150 ./images\let50.BMP
# Processed: 150 (30.060120240480963%)
# 151 ./images\let51.BMP
# 152 ./images\let52.BMP
# 153 ./images\let53.BMP
# 154 ./images\let54.BMP
# 155 ./images\let55.BMP
# 156 ./images\let56.BMP
# 157 ./images\let57.BMP
# 158 ./images\let58.BMP
# 159 ./images\let59.BMP
# 160 ./images\let60.BMP
# Processed: 160 (32.06412825651302%)
# 161 ./images\let61.BMP
# 162 ./images\let62.BMP
# 163 ./images\let63.BMP
# 164 ./images\let64.BMP
# 165 ./images\let65.BMP
# 166 ./images\let66.BMP
# 167 ./images\let67.BMP
# 168 ./images\let68.BMP
# 169 ./images\let69.BMP
# 170 ./images\let70.BMP
# Processed: 170 (34.06813627254509%)
# 171 ./images\let71.BMP
# 172 ./images\let72.BMP
# 173 ./images\let73.BMP
# 174 ./images\let74.BMP
# 175 ./images\let75.BMP
# 176 ./images\let76.BMP
# 177 ./images\let77.BMP
# 178 ./images\let78.BMP
# 179 ./images\let79.BMP
# 180 ./images\let80.BMP
# Processed: 180 (36.07214428857716%)
# 181 ./images\let81.BMP
# 182 ./images\let82.BMP
# 183 ./images\let83.BMP
# 184 ./images\let84.BMP
# 185 ./images\let85.BMP
# 186 ./images\let86.BMP
# 187 ./images\let87.BMP
# 188 ./images\let88.BMP
# 189 ./images\let89.BMP
# 190 ./images\let90.BMP
# Processed: 190 (38.07615230460922%)
# 191 ./images\let91.BMP
# 192 ./images\let92.BMP
# 193 ./images\let93.BMP
# 194 ./images\let94.BMP
# 195 ./images\let95.BMP
# 196 ./images\let96.BMP
# 197 ./images\let97.BMP
# 198 ./images\let98.BMP
# 199 ./images\let99.BMP
# 200 ./images\mod01.BMP
# Processed: 200 (40.08016032064128%)
# 201 ./images\mod02.BMP
# 202 ./images\mod03.BMP
# 203 ./images\mod04.BMP
# 204 ./images\mod05.BMP
# 205 ./images\mod06.BMP
# 206 ./images\mod07.BMP
# 207 ./images\mod08.BMP
# 208 ./images\mod09.BMP
# 209 ./images\mod10.BMP
# 210 ./images\mod100.BMP
# Processed: 210 (42.08416833667334%)
# 211 ./images\mod11.BMP
# 212 ./images\mod12.BMP
# 213 ./images\mod13.BMP
# 214 ./images\mod14.BMP
# 215 ./images\mod15.BMP
# 216 ./images\mod16.BMP
# 217 ./images\mod17.BMP
# 218 ./images\mod18.BMP
# 219 ./images\mod19.BMP
# 220 ./images\mod20.BMP
# Processed: 220 (44.08817635270541%)
# 221 ./images\mod21.BMP
# 222 ./images\mod22.BMP
# 223 ./images\mod23.BMP
# 224 ./images\mod24.BMP
# 225 ./images\mod25.BMP
# 226 ./images\mod26.BMP
# 227 ./images\mod27.BMP
# 228 ./images\mod28.BMP
# 229 ./images\mod29.BMP
# 230 ./images\mod30.BMP
# Processed: 230 (46.09218436873748%)
# 231 ./images\mod31.BMP
# 232 ./images\mod32.BMP
# 233 ./images\mod33.BMP
# 234 ./images\mod34.BMP
# 235 ./images\mod35.BMP
# 236 ./images\mod36.BMP
# 237 ./images\mod37.BMP
# 238 ./images\mod38.BMP
# 239 ./images\mod39.BMP
# 240 ./images\mod40.BMP
# Processed: 240 (48.09619238476954%)
# 241 ./images\mod41.BMP
# 242 ./images\mod42.BMP
# 243 ./images\mod43.BMP
# 244 ./images\mod44.BMP
# 245 ./images\mod45.BMP
# 246 ./images\mod46.BMP
# 247 ./images\mod47.BMP
# 248 ./images\mod48.BMP
# 249 ./images\mod49.BMP
# 250 ./images\mod50.BMP
# Processed: 250 (50.100200400801604%)
# 251 ./images\mod51.BMP
# 252 ./images\mod52.BMP
# 253 ./images\mod53.BMP
# 254 ./images\mod54.BMP
# 255 ./images\mod55.BMP
# 256 ./images\mod56.BMP
# 257 ./images\mod57.BMP
# 258 ./images\mod58.BMP
# 259 ./images\mod59.BMP
# 260 ./images\mod60.BMP
# Processed: 260 (52.104208416833664%)
# 261 ./images\mod61.BMP
# 262 ./images\mod62.BMP
# 263 ./images\mod63.BMP
# 264 ./images\mod64.BMP
# 265 ./images\mod65.BMP
# 266 ./images\mod66.BMP
# 267 ./images\mod67.BMP
# 268 ./images\mod68.BMP
# 269 ./images\mod69.BMP
# 270 ./images\mod70.BMP
# Processed: 270 (54.10821643286573%)
# 271 ./images\mod71.BMP
# 272 ./images\mod72.BMP
# 273 ./images\mod73.BMP
# 274 ./images\mod74.BMP
# 275 ./images\mod75.BMP
# 276 ./images\mod76.BMP
# 277 ./images\mod77.BMP
# 278 ./images\mod78.BMP
# 279 ./images\mod79.BMP
# 280 ./images\mod80.BMP
# Processed: 280 (56.1122244488978%)
# 281 ./images\mod81.BMP
# 282 ./images\mod82.BMP
# 283 ./images\mod83.BMP
# 284 ./images\mod84.BMP
# 285 ./images\mod85.BMP
# 286 ./images\mod86.BMP
# 287 ./images\mod87.BMP
# 288 ./images\mod88.BMP
# 289 ./images\mod89.BMP
# 290 ./images\mod90.BMP
# Processed: 290 (58.11623246492986%)
# 291 ./images\mod91.BMP
# 292 ./images\mod92.BMP
# 293 ./images\mod93.BMP
# 294 ./images\mod94.BMP
# 295 ./images\mod95.BMP
# 296 ./images\mod96.BMP
# 297 ./images\mod97.BMP
# 298 ./images\mod98.BMP
# 299 ./images\mod99.BMP
# 300 ./images\para01.BMP
# Processed: 300 (60.120240480961925%)
# 301 ./images\para02.BMP
# 302 ./images\para03.BMP
# 303 ./images\para04.BMP
# 304 ./images\para05.BMP
# 305 ./images\para06.BMP
# 306 ./images\para07.BMP
# 307 ./images\para08.BMP
# 308 ./images\para09.BMP
# 309 ./images\para10.BMP
# 310 ./images\para11.BMP
# Processed: 310 (62.124248496993985%)
# 311 ./images\para12.BMP
# 312 ./images\para13.BMP
# 313 ./images\para14.BMP
# 314 ./images\para15.BMP
# 315 ./images\para16.BMP
# 316 ./images\para17.BMP
# 317 ./images\para18.BMP
# 318 ./images\para19.BMP
# 319 ./images\para20.BMP
# 320 ./images\para21.BMP
# Processed: 320 (64.12825651302605%)
# 321 ./images\para22.BMP
# 322 ./images\para23.BMP
# 323 ./images\para24.BMP
# 324 ./images\para25.BMP
# 325 ./images\para26.BMP
# 326 ./images\para27.BMP
# 327 ./images\para28.BMP
# 328 ./images\para29.BMP
# 329 ./images\para30.BMP
# 330 ./images\para31.BMP
# Processed: 330 (66.13226452905812%)
# 331 ./images\para32.BMP
# 332 ./images\para33.BMP
# 333 ./images\para34.BMP
# 334 ./images\para35.BMP
# 335 ./images\para36.BMP
# 336 ./images\para37.BMP
# 337 ./images\para38.BMP
# 338 ./images\para39.BMP
# 339 ./images\para40.BMP
# 340 ./images\para41.BMP
# Processed: 340 (68.13627254509018%)
# 341 ./images\para42.BMP
# 342 ./images\para43.BMP
# 343 ./images\para44.BMP
# 344 ./images\para45.BMP
# 345 ./images\para46.BMP
# 346 ./images\para47.BMP
# 347 ./images\para48.BMP
# 348 ./images\para49.BMP
# 349 ./images\para50.BMP
# 350 ./images\super01.BMP
# Processed: 350 (70.14028056112224%)
# 351 ./images\super02.BMP
# 352 ./images\super03.BMP
# 353 ./images\super04.BMP
# 354 ./images\super05.BMP
# 355 ./images\super06.BMP
# 356 ./images\super07.BMP
# 357 ./images\super08.BMP
# 358 ./images\super09.BMP
# 359 ./images\super10.BMP
# 360 ./images\super11.BMP
# Processed: 360 (72.14428857715431%)
# 361 ./images\super12.BMP
# 362 ./images\super13.BMP
# 363 ./images\super14.BMP
# 364 ./images\super15.BMP
# 365 ./images\super16.BMP
# 366 ./images\super17.BMP
# 367 ./images\super18.BMP
# 368 ./images\super19.BMP
# 369 ./images\super20.BMP
# 370 ./images\super21.BMP
# Processed: 370 (74.14829659318637%)
# 371 ./images\super22.BMP
# 372 ./images\super23.BMP
# 373 ./images\super24.BMP
# 374 ./images\super25.BMP
# 375 ./images\super26.BMP
# 376 ./images\super27.BMP
# 377 ./images\super28.BMP
# 378 ./images\super29.BMP
# 379 ./images\super30.BMP
# 380 ./images\super31.BMP
# Processed: 380 (76.15230460921843%)
# 381 ./images\super32.BMP
# 382 ./images\super33.BMP
# 383 ./images\super34.BMP
# 384 ./images\super35.BMP
# 385 ./images\super36.BMP
# 386 ./images\super37.BMP
# 387 ./images\super38.BMP
# 388 ./images\super39.BMP
# 389 ./images\super40.BMP
# 390 ./images\super41.BMP
# Processed: 390 (78.15631262525051%)
# 391 ./images\super42.BMP
# 392 ./images\super43.BMP
# 393 ./images\super44.BMP
# 394 ./images\super46.BMP
# 395 ./images\super47.BMP
# 396 ./images\super48.BMP
# 397 ./images\super49.BMP
# 398 ./images\super50.BMP
# 399 ./images\svar01.BMP
# 400 ./images\svar02.BMP
# Processed: 400 (80.16032064128257%)
# 401 ./images\svar03.BMP
# 402 ./images\svar04.BMP
# 403 ./images\svar05.BMP
# 404 ./images\svar06.BMP
# 405 ./images\svar07.BMP
# 406 ./images\svar09.BMP
# 407 ./images\svar10.BMP
# 408 ./images\svar100.BMP
# 409 ./images\svar101.BMP
# 410 ./images\svar102.BMP
# Processed: 410 (82.16432865731463%)
# 411 ./images\svar103.BMP
# 412 ./images\svar104.BMP
# 413 ./images\svar105.BMP
# 414 ./images\svar106.BMP
# 415 ./images\svar11.BMP
# 416 ./images\svar12.BMP
# 417 ./images\svar13.BMP
# 418 ./images\svar14.BMP
# 419 ./images\svar15.BMP
# 420 ./images\svar16.BMP
# Processed: 420 (84.16833667334669%)
# 421 ./images\svar17.BMP
# 422 ./images\svar18.BMP
# 423 ./images\svar19.BMP
# 424 ./images\svar20.BMP
# 425 ./images\svar21.BMP
# 426 ./images\svar22.BMP
# 427 ./images\svar23.BMP
# 428 ./images\svar24.BMP
# 429 ./images\svar25.BMP
# 430 ./images\svar26.BMP
# Processed: 430 (86.17234468937876%)
# 431 ./images\svar27.BMP
# 432 ./images\svar28.BMP
# 433 ./images\svar29.BMP
# 434 ./images\svar30.BMP
# 435 ./images\svar31.BMP
# 436 ./images\svar32.BMP
# 437 ./images\svar33.BMP
# 438 ./images\svar34.BMP
# 439 ./images\svar35.BMP
# 440 ./images\svar36.BMP
# Processed: 440 (88.17635270541082%)
# 441 ./images\svar37.BMP
# 442 ./images\svar38.BMP
# 443 ./images\svar39.BMP
# 444 ./images\svar40.BMP
# 445 ./images\svar41.BMP
# 446 ./images\svar42.BMP
# 447 ./images\svar43.BMP
# 448 ./images\svar44.BMP
# 449 ./images\svar46.BMP
# 450 ./images\svar47.BMP
# Processed: 450 (90.18036072144288%)
# 451 ./images\svar48.BMP
# 452 ./images\svar49.BMP
# 453 ./images\svar50.BMP
# 454 ./images\svar51.BMP
# 455 ./images\svar52.BMP
# 456 ./images\svar53.BMP
# 457 ./images\svar54.BMP
# 458 ./images\svar56.BMP
# 459 ./images\svar58.BMP
# 460 ./images\svar59.BMP
# Processed: 460 (92.18436873747495%)
# 461 ./images\svar60.BMP
# 462 ./images\svar61.BMP
# 463 ./images\svar62.BMP
# 464 ./images\svar63.BMP
# 465 ./images\svar64.BMP
# 466 ./images\svar65.BMP
# 467 ./images\svar66.BMP
# 468 ./images\svar67.BMP
# 469 ./images\svar69.BMP
# 470 ./images\svar70.BMP
# Processed: 470 (94.18837675350701%)
# 471 ./images\svar71.BMP
# 472 ./images\svar72.BMP
# 473 ./images\svar73.BMP
# 474 ./images\svar74.BMP
# 475 ./images\svar75.BMP
# 476 ./images\svar76.BMP
# 477 ./images\svar77.BMP
# 478 ./images\svar78.BMP
# 479 ./images\svar79.BMP
# 480 ./images\svar80.BMP
# Processed: 480 (96.19238476953907%)
# 481 ./images\svar81.BMP
# 482 ./images\svar82.BMP
# 483 ./images\svar83.BMP
# 484 ./images\svar84.BMP
# 485 ./images\svar85.BMP
# 486 ./images\svar86.BMP
# 487 ./images\svar87.BMP
# 488 ./images\svar88.BMP
# 489 ./images\svar89.BMP
# 490 ./images\svar90.BMP
# Processed: 490 (98.19639278557115%)
# 491 ./images\svar92.BMP
# 492 ./images\svar93.BMP
# 493 ./images\svar94.BMP
# 494 ./images\svar95.BMP
# 495 ./images\svar96.BMP
# 496 ./images\svar97.BMP
# 497 ./images\svar98.BMP
# 498 ./images\svar99.BMP

# %%
# Out:
# array([8.78473598e+01, 9.37391162e+01, 1.34976313e+03, 6.38409028e+01,
#        6.78583337e+01, 1.01362615e+00, 2.49564884e+02, 5.49562008e+01,
#        5.71415425e+01, 5.48272876e+01, 6.12934212e+01, 3.19639279e+00])
